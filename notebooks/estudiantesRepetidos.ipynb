# %%
import pandas as pd

df = pd.read_csv('../data/dataset_completo_final.csv', encoding='utf-8-sig')

df_activos_sin_eng = df[
    (~df['estado'].isin(['RETIRADO', 'SIN_NOTA'])) &
    (df['engagement_hasta_p1'] == 0)
]

print(f'Total activos sin engagement: {len(df_activos_sin_eng)}')
print(df_activos_sin_eng[['id_estudiante', 'semestre', 'estado', 'engagement_hasta_p1']].to_string(index=False))
# Out:
# Total activos sin engagement: 52
#                                                    id_estudiante  semestre  estado  engagement_hasta_p1
# 10218c9778d97cf375ba894b69cb5938f4c105a830eb89007984a42652d73c64    202320 REPROBÓ                  0.0
# 1db1f5efdb3558b62a865a1bd2b8189f3dbd24fc99a8ad56dbed4a3159b7fc9f    202320  APROBÓ                  0.0
# 1f20040f2eed15800f9b2fa45e53eb12ad2dc2a61d44432f48d8b5f9ea301ccd    202320  APROBÓ                  0.0
# 2238f7d1dd0633c3b4583243299c8fd61e8a4d915e5f3837a0d8d6edd9b63463    202320  APROBÓ                  0.0
# 2295e56d61cfa0a2824543c80f9b5d4b463e8f4915f6bcda5156242e1182a840    202320  APROBÓ                  0.0
# 2684753c6ce7ad40b989d8156006463e8b7dc242a687c10c8bf5e1505528d55d    202320  APROBÓ                  0.0
# 2c2754a8096695332b47dbee54ce59d6f62ae6f24e54809b1081e7fad479e444    202320  APROBÓ                  0.0
# 319ce8be1bf0e2fa8aedcc6a4a28ff7a987c3f371c480b9ea7834d97e61345e4    202320 REPROBÓ                  0.0
# ...
